# %%
import ee
import geemap
ee.Authenticate()
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=uaI92reiy5P_WAe7bn2Ne8iIAy2i6oh6bPTFluySvY0&tc=nFgrV7QAshkYNN_zRkV0UO0bDnt3JZvaKWR90zB5JaA&cc=7lAGOKe4fMdPmpAsIYUlhdov7IBOW0uNsDuvjOLDY_8>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=uaI92reiy5P_WAe7bn2Ne8iIAy2i6oh6bPTFluySvY0&tc=nFgrV7QAshkYNN_zRkV0UO0bDnt3JZvaKWR90zB5JaA&cc=7lAGOKe4fMdPmpAsIYUlhdov7IBOW0uNsDuvjOLDY_8</a></p>
#         <p>The authorization workflow will generate a code, which you
#         should paste in the box below</p>
# Successfully saved authorization token.
# ...
